# %%
import sys

p2 = {}
p3 = {}
p4 = {}
stamp = []

def possibleWith2():
    global stamp,p2
    p2 = {}
    index1 = 0
    index2 = 0
    max = 0
    for index1 in range(len(stamp)):
        for index2 in range(len(stamp)):
            p2[stamp[index1]+stamp[index2]] = True
    return p2
            
def possibleWith3():
    global stamp,p2,p3
    p3={}
    index3 = 0
    for index in range(len(stamp)):
        for p in p2.keys():
            p3[stamp[index]+p] = True
    return p3

def possibleWith4():
    global stamp,p2,p3,p4
    p4={}
    index4 = 0
    for index in range(len(stamp)):
        for p in p3.keys():
            p4[stamp[index]+p] = True
    return p4


def calcMax():
    global stamp,p2,p3,p4
    p2 = possibleWith2()
    p3 = possibleWith3()
    p4 = possibleWith4()
#     print(sorted(p2.keys()))
#     print(sorted(p3.keys()))
#     print(sorted(p4.keys()))
    n = 0
    ok = True
    while ok:
        if n in p4.keys():
            n = n + 1
        else:
            ok = False
    return n-1
    
largestN = 0
for s2 in list(range(2, 40)):
    stamp=[0,1]
    n1 = calcMax()
    if s2 <= n1+1:
        stamp = [0,1,s2]
        n2 = calcMax()
        for s3 in list(range(s2+2, 100)):
            if s3 <= n2+1:
                stamp=[0,1,s2,s3]
                n3 = calcMax()
                if n3 > largestN:
                    largestN = n3
                    largest = stamp.copy()
print("3 stamps: {} -> {}".format(largest, largestN))

largestN = 0
for s2 in list(range(2, 40)):
    stamp=[0,1]
    n1 = calcMax()
    if s2 <= n1+1:
        stamp = [0,1,s2]
        n2 = calcMax()
        for s3 in list(range(s2+2, 100)):
            if s3 <= n2+1:
                stamp=[0,1,s2,s3]
                n3 = calcMax()
                for s4 in list(range(s3+2, 100)):
                    if s4 <= n3+1:
                        stamp=[0,1,s2,s3,s4]
                        n4 = calcMax()
                        if n4 > largestN:
                            largestN = n4
                            largest = stamp.copy()
print("4 stamps: {} -> {}".format(largest, largestN))

largestN = 0
for s2 in list(range(2, 40)):
    stamp=[0,1]
    n1 = calcMax()
    if s2 <= n1+1:
        stamp = [0,1,s2]
        n2 = calcMax()
        for s3 in list(range(s2+2, 100)):
            if s3 <= n2+1:
                stamp=[0,1,s2,s3]
                n3 = calcMax()
                for s4 in list(range(s3+2, 100)):
                    if s4 <= n3+1:
                        stamp=[0,1,s2,s3,s4]
                        n4 = calcMax()
                        for s5 in list(range(s4+2, 100)):
                            if s5 <= n4+1:
                                stamp=[0,1,s2,s3,s4,s5]
                                n5 = calcMax()
                                if n5 > largestN:
                                    largestN = n5
                                    largest = stamp.copy()
print("5 stamps: {} -> {}".format(largest, largestN))

largestN = 0
for s2 in list(range(2, 40)):
    stamp=[0,1]
    n1 = calcMax()
    if s2 <= n1+1:
        stamp = [0,1,s2]
        n2 = calcMax()
        for s3 in list(range(s2+2, 20)):
            if s3 <= n2+1:
                stamp=[0,1,s2,s3]
                n3 = calcMax()
                for s4 in list(range(s3+2, 30)):
                    if s4 <= n3+1:
                        stamp=[0,1,s2,s3,s4]
                        n4 = calcMax()
                        for s5 in list(range(s4+2, 100)):
                            if s5 <= n4+1:
                                stamp=[0,1,s2,s3,s4,s5]
                                n5 = calcMax()
                                for s6 in list(range(s5+2, 100)):
                                    if s6 <= n5+1:
                                        stamp=[0,1,s2,s3,s4,s5,s6]
                                        n6 = calcMax()
                                        if n6 > largestN:
                                            largestN = n6
                                            largest = stamp.copy()
print("6 stamps: {} -> {}".format(largest, largestN))

largestN = 0
for s2 in list(range(2, 40)):
    stamp=[0,1]
    n1 = calcMax()
    if s2 <= n1+1:
        stamp = [0,1,s2]
        n2 = calcMax()
        for s3 in list(range(s2+2, 20)):
            if s3 <= n2+1:
                stamp=[0,1,s2,s3]
                n3 = calcMax()
                for s4 in list(range(s3+2, 30)):
                    if s4 <= n3+1:
                        stamp=[0,1,s2,s3,s4]
                        n4 = calcMax()
                        for s5 in list(range(s4+2, 50)):
                            if s5 <= n4+1:
                                stamp=[0,1,s2,s3,s4,s5]
                                n5 = calcMax()
                                for s6 in list(range(s5+2, 80)):
                                    if s6 <= n5+1:
                                        stamp=[0,1,s2,s3,s4,s5,s6]
                                        n6 = calcMax()
                                        for s7 in list(range(s6+2, 100)):
                                            if s7 <= n6+1:
                                                stamp=[0,1,s2,s3,s4,s5,s6,s7]
                                                n7 = calcMax()
                                                if n7 > largestN:
                                                    largestN = n7
                                                    largest = stamp.copy()
print("7 stamps: {} -> {}".format(largest, largestN))

largestN = 0
for s2 in list(range(2, 40)):
    stamp=[0,1]
    n1 = calcMax()
    if s2 <= n1+1:
        stamp = [0,1,s2]
        n2 = calcMax()
        for s3 in list(range(s2+2, 20)):
            if s3 <= n2+1:
                stamp=[0,1,s2,s3]
                n3 = calcMax()
                for s4 in list(range(s3+2, 30)):
                    if s4 <= n3+1:
                        stamp=[0,1,s2,s3,s4]
                        n4 = calcMax()
                        for s5 in list(range(s4+2, 50)):
                            if s5 <= n4+1:
                                stamp=[0,1,s2,s3,s4,s5]
                                n5 = calcMax()
                                for s6 in list(range(s5+2, 60)):
                                    if s6 <= n5+1:
                                        stamp=[0,1,s2,s3,s4,s5,s6]
                                        n6 = calcMax()
                                        for s7 in list(range(s6+2, 100)):
                                            if s7 <= n6+1:
                                                stamp=[0,1,s2,s3,s4,s5,s6,s7]
                                                n7 = calcMax()
                                                for s8 in list(range(s7+2, 130)):
                                                    if s8 <= n7+1:
                                                        stamp=[0,1,s2,s3,s4,s5,s6,s7,s8]
                                                        n8 = calcMax()
                                                        if n8 > largestN:
                                                            largestN = n8
                                                            largest = stamp.copy()
print("8 stamps: {} -> {}".format(largest, largestN))
# Out:
# 3 stamps: [0, 1, 5, 8] -> 26
# 4 stamps: [0, 1, 3, 11, 18] -> 44
# 5 stamps: [0, 1, 3, 11, 15, 32] -> 70
# 6 stamps: [0, 1, 4, 9, 16, 38, 49] -> 108
